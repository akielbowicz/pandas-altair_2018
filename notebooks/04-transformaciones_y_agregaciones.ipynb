# %% [markdown]
# # Transformaciones de los datos
#
# En este cuaderno vamos a ver cuales son los métodos básicos que brinda **pandas** para realizar transformaciones en los datos. Y como realizar operaciones similares directamente en **Altair**.

# %%
import pandas as pd
import altair as alt
